# %%
import pandas as pd
import requests
import numpy as np
import re

# %%
# Get the list of data files to be loaded 
files = '''DATA_SRC.txt:     text/plain; charset=us-ascii
DATSRCLN.txt:     text/plain; charset=us-ascii
DERIV_CD.txt:     text/plain; charset=us-ascii
FD_GROUP.txt:     text/plain; charset=us-ascii
FOOD_DES.txt:     text/plain; charset=iso-8859-1
FOOTNOTE.txt:     text/plain; charset=iso-8859-1
LANGDESC.txt:     text/plain; charset=us-ascii
LANGUAL.txt:      text/plain; charset=us-ascii
NUTR_DEF.txt:     text/plain; charset=iso-8859-1
NUT_DATA.txt:     text/plain; charset=us-ascii
SRC_CD.txt:       text/plain; charset=us-ascii
WEIGHT.txt:       text/plain; charset=us-ascii'''.split('\n')

# %%
files
# Out:
# ['DATA_SRC.txt:     text/plain; charset=us-ascii',
#  'DATSRCLN.txt:     text/plain; charset=us-ascii',
#  'DERIV_CD.txt:     text/plain; charset=us-ascii',
#  'FD_GROUP.txt:     text/plain; charset=us-ascii',
#  'FOOD_DES.txt:     text/plain; charset=iso-8859-1',
#  'FOOTNOTE.txt:     text/plain; charset=iso-8859-1',
#  'LANGDESC.txt:     text/plain; charset=us-ascii',
#  'LANGUAL.txt:      text/plain; charset=us-ascii',
#  'NUTR_DEF.txt:     text/plain; charset=iso-8859-1',
#  'NUT_DATA.txt:     text/plain; charset=us-ascii',
#  'SRC_CD.txt:       text/plain; charset=us-ascii',
#  'WEIGHT.txt:       text/plain; charset=us-ascii']

# %%
files[0]
# Out:
# 'DATA_SRC.txt:     text/plain; charset=us-ascii'

# %%
test = files[0]
regex = r"^(.+txt).*charset=(.+)$"
re.findall(regex, test)
# Out:
# [('DATA_SRC.txt', 'us-ascii')]

# %%
encodings = [re.findall(regex, file_)[0] for file_ in files ]
encodings
# Out:
# [('DATA_SRC.txt', 'us-ascii'),
#  ('DATSRCLN.txt', 'us-ascii'),
#  ('DERIV_CD.txt', 'us-ascii'),
#  ('FD_GROUP.txt', 'us-ascii'),
#  ('FOOD_DES.txt', 'iso-8859-1'),
#  ('FOOTNOTE.txt', 'iso-8859-1'),
#  ('LANGDESC.txt', 'us-ascii'),
#  ('LANGUAL.txt', 'us-ascii'),
#  ('NUTR_DEF.txt', 'iso-8859-1'),
#  ('NUT_DATA.txt', 'us-ascii'),
#  ('SRC_CD.txt', 'us-ascii'),
#  ('WEIGHT.txt', 'us-ascii')]

# %%
encodings_dict = {key: val for key,val in encodings }
encodings_dict
# Out:
# {'DATA_SRC.txt': 'us-ascii',
#  'DATSRCLN.txt': 'us-ascii',
#  'DERIV_CD.txt': 'us-ascii',
#  'FD_GROUP.txt': 'us-ascii',
#  'FOOD_DES.txt': 'iso-8859-1',
#  'FOOTNOTE.txt': 'iso-8859-1',
#  'LANGDESC.txt': 'us-ascii',
#  'LANGUAL.txt': 'us-ascii',
#  'NUTR_DEF.txt': 'iso-8859-1',
#  'NUT_DATA.txt': 'us-ascii',
#  'SRC_CD.txt': 'us-ascii',
#  'WEIGHT.txt': 'us-ascii'}

# %%
filename = "WEIGHT.txt"
encoding=encodings_dict[filename]

# %%
filename = "WEIGHT.txt"
dir = "SR-Leg_ASC"
file_path = "./{}/{}".format(dir, filename)
print(file_path)
# Out:
# ./SR-Leg_ASC/WEIGHT.txt

# %%
filename = "WEIGHT.txt"
txt=filename[:-4]
print(txt)
# Out:
# WEIGHT

# %%
for i in encodings_dict:
    print (i, ' - ', encodings_dict[i])
# Out:
# DATA_SRC.txt  -  us-ascii
# DATSRCLN.txt  -  us-ascii
# DERIV_CD.txt  -  us-ascii
# FD_GROUP.txt  -  us-ascii
# FOOD_DES.txt  -  iso-8859-1
# FOOTNOTE.txt  -  iso-8859-1
# LANGDESC.txt  -  us-ascii
# LANGUAL.txt  -  us-ascii
# NUTR_DEF.txt  -  iso-8859-1
# NUT_DATA.txt  -  us-ascii
# SRC_CD.txt  -  us-ascii
# WEIGHT.txt  -  us-ascii

# %%
dfs = {}
dir = "SR-Leg_ASC"
for i in encodings_dict:
    filename=i
    encoding = encodings_dict[filename]
    file_path = "./{}/{}".format(dir, filename)
    txt=filename[:-4]
    dfs[txt] = pd.read_csv(file_path, encoding = encoding, sep="^", header=None)
    dfs[txt].replace(regex=True,inplace=True,to_replace=r'~',value=r'')
# Out:
# /var/folders/b3/sw4s_d3s4d5frrqwl56qmt7r0000gn/T/ipykernel_25146/2625467676.py:8: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfs[txt] = pd.read_csv(file_path, encoding = encoding, sep="^", header=None)

# %%
dfs['DATA_SRC'].columns = ['DataSrc_ID', 'Authors','Title','Year','Journal',
                           'Vol_City','Issue_State','Start_Page','End_Page']

dfs['DATSRCLN'].columns = ['NDB_No','Nutr_No','DataSrc_ID']
dfs['DERIV_CD'].columns = ['Deriv_Cd','Deriv_Desc']
dfs['FD_GROUP'].columns = ['FdGrp_Cd','FdGrp_Desc']
dfs['FOOD_DES'].columns = ['NDB_No','FdGrp_Cd','Long_Desc','Shrt_Desc','ComName','ManufacName','Survey',
                           'Ref_desc','Refuse','SciName','N_Factor','Pro_Factor','Fat_Factor','CHO_Factor']
dfs['FOOTNOTE'].columns = ['NDB_No','Footnt_No','Footnt_Typ','Nutr_No','Footnt_Txt']

dfs['LANGDESC'].columns = ['Factor_Code','Description']
dfs['LANGUAL'].columns = ['NDB_No','Factor_Code']
dfs['NUTR_DEF'].columns = ['Nutr_No','Units','Tagname','NutrDesc','Num_Dec','SR_Order']
dfs['NUT_DATA'].columns = ['NDB_No','Nutr_No','Nutr_Val','Num_Data_Pts','Std_Error','Src_Cd','Deriv_Cd',
                           'Ref_NDB_No','Add_Nutr_Mark','Num_Studies','Min','Max','DF','Low_EB','Up_EB',
                           'Stat_cmt','AddMod_Date']
dfs['SRC_CD'].columns = ['Src_Cd','SrcCd_Desc']
dfs['WEIGHT'].columns = ['NDB_No','Seq','Amount','Msre_Desc','Gm_Wgt','Num_Data_Pts','Std_Dev']

# %%
print('**** DATA_SRC ****')
print(dfs['DATA_SRC'].dtypes, dfs['DATA_SRC'].shape)
print('*' * 20)

print('**** DATSRCLN ****')
print(dfs['DATSRCLN'].dtypes, dfs['DATSRCLN'].shape)
print('*' * 20)

print('**** DERIV_CD ****')
print(dfs['DERIV_CD'].dtypes,dfs['DERIV_CD'].shape)
print('*' * 20)

print('**** FD_GROUP ****')
print(dfs['FD_GROUP'].dtypes,dfs['FD_GROUP'].shape)
print('*' * 20)

print('**** FOOD_DES ****')
print(dfs['FOOD_DES'].dtypes,dfs['FOOD_DES'].shape)
print('*' * 20)

print('**** FOOTNOTE ****')
print(dfs['FOOTNOTE'].dtypes,dfs['FOOTNOTE'].shape)
print('*' * 20)


print('**** LANGDESC ****')
print(dfs['LANGDESC'].dtypes, dfs['LANGDESC'].shape)
print('*' * 20)

print('**** LANGUAL ****')
print(dfs['LANGUAL'].dtypes, dfs['LANGUAL'].shape)
print('*' * 20)

print('**** NUTR_DEF ****')
print(dfs['NUTR_DEF'].dtypes, dfs['NUTR_DEF'].shape)
print('*' * 20)

print('**** NUT_DATA ****')
print(dfs['NUT_DATA'].dtypes, dfs['NUT_DATA'].shape)
print('*' * 20)

print('**** SRC_CD ****')
print(dfs['SRC_CD'].dtypes, dfs['SRC_CD'].shape)
print('*' * 20)

print('**** WEIGHT ****')
print(dfs['WEIGHT'].dtypes, dfs['WEIGHT'].shape)
print('*' * 20)
# Out:
# **** DATA_SRC ****
# DataSrc_ID     object
# Authors        object
# Title          object
# Year           object
# Journal        object
# Vol_City       object
# Issue_State    object
# Start_Page     object
# End_Page       object
# dtype: object (606, 9)
# ********************
# **** DATSRCLN ****
# NDB_No        object
# Nutr_No       object
# DataSrc_ID    object
# dtype: object (228457, 3)
# ********************
# **** DERIV_CD ****
# Deriv_Cd      object
# Deriv_Desc    object
# dtype: object (57, 2)
# ********************
# **** FD_GROUP ****
# FdGrp_Cd      object
# FdGrp_Desc    object
# dtype: object (25, 2)
# ********************
# **** FOOD_DES ****
# NDB_No          object
# FdGrp_Cd        object
# Long_Desc       object
# Shrt_Desc       object
# ComName         object
# ManufacName     object
# Survey          object
# Ref_desc        object
# Refuse         float64
# SciName         object
# N_Factor       float64
# Pro_Factor     float64
# Fat_Factor     float64
# CHO_Factor     float64
# dtype: object (7793, 14)
# ********************
# **** FOOTNOTE ****
# NDB_No        object
# Footnt_No     object
# Footnt_Typ    object
# Nutr_No       object
# Footnt_Txt    object
# dtype: object (537, 5)
# ********************
# **** LANGDESC ****
# Factor_Code    object
# Description    object
# dtype: object (773, 2)
# ********************
# **** LANGUAL ****
# NDB_No         object
# Factor_Code    object
# dtype: object (37910, 2)
# ********************
# **** NUTR_DEF ****
# Nutr_No     object
# Units       object
# Tagname     object
# NutrDesc    object
# Num_Dec     object
# SR_Order     int64
# dtype: object (149, 6)
# ********************
# **** NUT_DATA ****
# NDB_No            object
# Nutr_No           object
# Nutr_Val         float64
# Num_Data_Pts       int64
# Std_Error        float64
# Src_Cd            object
# Deriv_Cd          object
# Ref_NDB_No        object
# Add_Nutr_Mark     object
# Num_Studies      float64
# Min              float64
# Max              float64
# DF               float64
# Low_EB           float64
# Up_EB            float64
# Stat_cmt          object
# AddMod_Date       object
# dtype: object (644125, 17)
# ********************
# **** SRC_CD ****
# Src_Cd        object
# SrcCd_Desc    object
# dtype: object (10, 2)
# ********************
# **** WEIGHT ****
# NDB_No           object
# Seq              object
# Amount          float64
# Msre_Desc        object
# Gm_Wgt          float64
# Num_Data_Pts    float64
# Std_Dev         float64
# dtype: object (14449, 7)
# ********************

# %%
dfs['DATA_SRC'].head(3)
# Out:
#   DataSrc_ID                                            Authors  \
# 0      D2028  A. Sanchez-Marroquin, A. Feria-Morales, S. May...
# 1      D3296                           C.E. Damon, B.C. Pettitt
# 2      D3315               W.J. Hurst, R.A. Martin, B.L. Zoumas
#
#                                                Title  Year  \
# 0  Processing, nutritional quality and sensory ev...  1987
# 1  Sugars and Sugar Products: High Performance Li...  1980
# 2  Application of HPLC to Characterization of Ind...  1979
#
#                    Journal Vol_City Issue_State Start_Page End_Page
# 0  Journal of Food Science       52           5        NaN      NaN
# 1                  J. AOAC       63           3        476      480
# 2  Journal of Food Science       44         NaN        892      893

# %%
dfs['DATSRCLN'].head(3)
# Out:
#   NDB_No Nutr_No DataSrc_ID
# 0  01001     301        S10
# 1  01001     301        S11
# 2  01001     301        S12

# %%
dfs['DERIV_CD'].head(3)
# Out:
#   Deriv_Cd                                         Deriv_Desc
# 0        A                                    Analytical data
# 1       AI  Analytical data; from the literature or  gover...
# 2       AR      Analytical data; derived by linear regression

# %%
dfs['FD_GROUP'].head(3)
# Out:
#   FdGrp_Cd              FdGrp_Desc
# 0     0100  Dairy and Egg Products
# 1     0200        Spices and Herbs
# 2     0300              Baby Foods

# %%
dfs['FOOD_DES'].head(3)
# Out:
#   NDB_No FdGrp_Cd                   Long_Desc               Shrt_Desc ComName  \
# 0  01001     0100              Butter, salted        BUTTER,WITH SALT     NaN
# 1  01002     0100  Butter, whipped, with salt  BUTTER,WHIPPED,W/ SALT     NaN
# 2  01003     0100       Butter oil, anhydrous    BUTTER OIL,ANHYDROUS     NaN
#
#   ManufacName Survey Ref_desc  Refuse SciName  N_Factor  Pro_Factor  \
# 0         NaN      Y      NaN     0.0     NaN      6.38        4.27
# 1         NaN      Y      NaN     0.0     NaN      6.38         NaN
# 2         NaN      Y      NaN     0.0     NaN      6.38        4.27
#
#    Fat_Factor  CHO_Factor
# 0        8.79        3.87
# 1         NaN         NaN
# 2        8.79        3.87

# %%
dfs['FOOTNOTE'].head(3)
# Out:
#   NDB_No Footnt_No Footnt_Typ Nutr_No  \
# 0  09129        01          D     NaN
# 1  09130        01          D     NaN
# 2  09135        01          D     NaN
#
#                                           Footnt_Txt
# 0  Includes analysis of Higgins, Jumbo, and Roano...
# 1              Includes purple and white grape juice
# 2              Includes purple and white grape juice

# %%
dfs['LANGDESC'].head(3)
# Out:
#   Factor_Code                           Description
# 0       A0107  BAKERY PRODUCT, UNSWEETENED (US CFR)
# 1       A0113                SPICE OR HERB (US CFR)
# 2       A0125      GRAIN OR STARCH PRODUCT (US CFR)

# %%
dfs['LANGUAL'].head(3)
# Out:
#   NDB_No Factor_Code
# 0  02001       A0113
# 1  02001       A1272
# 2  02001       B1356

# %%
dfs['NUTR_DEF'].head(3)
# Out:
#   Nutr_No Units Tagname                     NutrDesc Num_Dec  SR_Order
# 0     203     g  PROCNT                      Protein       2       600
# 1     204     g     FAT            Total lipid (fat)       2       800
# 2     205     g  CHOCDF  Carbohydrate, by difference       2      1100

# %%
dfs['NUT_DATA'].head(3)
# Out:
#   NDB_No Nutr_No  Nutr_Val  Num_Data_Pts  Std_Error Src_Cd Deriv_Cd  \
# 0  01001     208     717.0             0        NaN      4       NC
# 1  01001     262       0.0             0        NaN      7        Z
# 2  01001     263       0.0             0        NaN      7        Z
#
#   Ref_NDB_No Add_Nutr_Mark  Num_Studies  Min  Max  DF  Low_EB  Up_EB Stat_cmt  \
# 0        NaN           NaN          NaN  NaN  NaN NaN     NaN    NaN      NaN
# 1        NaN           NaN          NaN  NaN  NaN NaN     NaN    NaN      NaN
# 2        NaN           NaN          NaN  NaN  NaN NaN     NaN    NaN      NaN
#
#   AddMod_Date
# 0  08/01/2010
# 1  02/01/2001
# 2  02/01/2001

# %%
dfs['SRC_CD'].head(3)
# Out:
#   Src_Cd                                         SrcCd_Desc
# 0      1              Analytical or derived from analytical
# 1     11  Aggregated data involving comb. of codes other...
# 2     12   Manufacturer's analytical; partial documentation

# %%
dfs['WEIGHT'].head(3)
# Out:
#   NDB_No Seq  Amount               Msre_Desc  Gm_Wgt  Num_Data_Pts  Std_Dev
# 0  01001   1     1.0  pat (1" sq, 1/3" high)     5.0           NaN      NaN
# 1  01001   2     1.0                    tbsp    14.2           NaN      NaN
# 2  01001   3     1.0                     cup   227.0           NaN      NaN

# %%
# Convert some of the identified columns as INT and FLOAT as per the document listed.

# Convert the identified columns into int and float of the dataframe 'NUT_DATA'.
dfs['NUT_DATA']['Src_Cd'] = dfs['NUT_DATA']['Src_Cd'].astype(int)

# Convert the identified columns into int of the dataframe 'SRC_CD'.
dfs['SRC_CD']['Src_Cd'] = dfs['SRC_CD']['Src_Cd'].astype(int)

# %%
# Merge the two dataframes - FOOD_DES and FD_GROUP on FdGrp_Cd
df_food_fdg = pd.merge(how ='left',
         left = dfs['FOOD_DES'],
         right = dfs['FD_GROUP'],
         on = 'FdGrp_Cd')

# %%
df_food_fdg.shape
# Out:
# (7793, 15)

# %%
df_food_fdg.head(3)
# Out:
#   NDB_No FdGrp_Cd                   Long_Desc               Shrt_Desc ComName  \
# 0  01001     0100              Butter, salted        BUTTER,WITH SALT     NaN
# 1  01002     0100  Butter, whipped, with salt  BUTTER,WHIPPED,W/ SALT     NaN
# 2  01003     0100       Butter oil, anhydrous    BUTTER OIL,ANHYDROUS     NaN
#
#   ManufacName Survey Ref_desc  Refuse SciName  N_Factor  Pro_Factor  \
# 0         NaN      Y      NaN     0.0     NaN      6.38        4.27
# 1         NaN      Y      NaN     0.0     NaN      6.38         NaN
# 2         NaN      Y      NaN     0.0     NaN      6.38        4.27
#
#    Fat_Factor  CHO_Factor              FdGrp_Desc
# 0        8.79        3.87  Dairy and Egg Products
# 1         NaN         NaN  Dairy and Egg Products
# 2        8.79        3.87  Dairy and Egg Products

# %%
df_food_fdg[['FdGrp_Cd','FdGrp_Desc']].groupby(by='FdGrp_Cd').count().sort_index( ascending=False).head()
# Out:
#           FdGrp_Desc
# FdGrp_Cd
# 3600             109
# 3500             165
# 2500             176
# 2200              81
# 2100             312

# %%
# Merge the two dataframes -nut_data and nutrient_def on nutrient number

df_nut_data_def = pd.merge(how ='left',
                          left = dfs['NUT_DATA'],
                          right = dfs['NUTR_DEF'],
                          on = 'Nutr_No')

# %%
df_nut_data_def.shape
# Out:
# (644125, 22)

# %%
df_nut_data_def.head(3)
# Out:
#   NDB_No Nutr_No  Nutr_Val  Num_Data_Pts  Std_Error  Src_Cd Deriv_Cd  \
# 0  01001     208     717.0             0        NaN       4       NC
# 1  01001     262       0.0             0        NaN       7        Z
# 2  01001     263       0.0             0        NaN       7        Z
#
#   Ref_NDB_No Add_Nutr_Mark  Num_Studies  ...  DF  Low_EB  Up_EB  Stat_cmt  \
# 0        NaN           NaN          NaN  ... NaN     NaN    NaN       NaN
# 1        NaN           NaN          NaN  ... NaN     NaN    NaN       NaN
# 2        NaN           NaN          NaN  ... NaN     NaN    NaN       NaN
#
#    AddMod_Date Units     Tagname     NutrDesc Num_Dec SR_Order
# 0   08/01/2010  kcal  ENERC_KCAL       Energy       0      300
# 1   02/01/2001    mg       CAFFN     Caffeine       0    18300
# 2   02/01/2001    mg      THEBRN  Theobromine       0    18400
#
# [3 rows x 22 columns]

# %%
# Merge the two dataframes - DATSRCLN  and DATA_SRC on DataSrc ID

df_SRC_SRCLN = pd.merge(how ='left',
                        left = dfs['DATA_SRC'],
                        right = dfs['DATSRCLN'],
                        on = 'DataSrc_ID')

# %%
df_SRC_SRCLN.shape
# Out:
# (228457, 11)

# %%
df_SRC_SRCLN.head(3)
# Out:
#   DataSrc_ID                                            Authors  \
# 0      D2028  A. Sanchez-Marroquin, A. Feria-Morales, S. May...
# 1      D2028  A. Sanchez-Marroquin, A. Feria-Morales, S. May...
# 2      D2028  A. Sanchez-Marroquin, A. Feria-Morales, S. May...
#
#                                                Title  Year  \
# 0  Processing, nutritional quality and sensory ev...  1987
# 1  Processing, nutritional quality and sensory ev...  1987
# 2  Processing, nutritional quality and sensory ev...  1987
#
#                    Journal Vol_City Issue_State Start_Page End_Page NDB_No  \
# 0  Journal of Food Science       52           5        NaN      NaN  20017
# 1  Journal of Food Science       52           5        NaN      NaN  20017
# 2  Journal of Food Science       52           5        NaN      NaN  20017
#
#   Nutr_No
# 0     203
# 1     204
# 2     207

# %%
# Merge the two dataframes - LANGUAL  and LANGDESC on Factor_Code
df_LANGUAL_DESC = pd.merge(how ='left',
                           left = dfs['LANGUAL'],
                           right = dfs['LANGDESC'],
                           on = 'Factor_Code')

# %%
df_LANGUAL_DESC.shape
# Out:
# (37910, 3)

# %%
df_LANGUAL_DESC.head(3)
# Out:
#   NDB_No Factor_Code                      Description
# 0  02001       A0113           SPICE OR HERB (US CFR)
# 1  02001       A1272  0200 SPICES AND HERBS (USDA SR)
# 2  02001       B1356                         ALLSPICE

# %%
df_LANGUAL_DESC['NDB_No'].value_counts().head()
# Out:
# NDB_No
# 05092    25
# 05101    25
# 05030    24
# 05085    24
# 05076    24
# Name: count, dtype: int64

# %%
# Sample a record with NDB_No '02001'
df_food_fdg[df_food_fdg['NDB_No']=='02001']
# Out:
#     NDB_No FdGrp_Cd                 Long_Desc        Shrt_Desc ComName  \
# 263  02001     0200  Spices, allspice, ground  ALLSPICE,GROUND     NaN
#
#     ManufacName Survey Ref_desc  Refuse         SciName  N_Factor  Pro_Factor  \
# 263         NaN    NaN      NaN     0.0  Pimenta dioica      6.25        3.36
#
#      Fat_Factor  CHO_Factor        FdGrp_Desc
# 263        8.37        2.35  Spices and Herbs

# %%
df_LANGUAL_DESC[df_LANGUAL_DESC['NDB_No']=='02001'].head(3)
# Out:
#   NDB_No Factor_Code                      Description
# 0  02001       A0113           SPICE OR HERB (US CFR)
# 1  02001       A1272  0200 SPICES AND HERBS (USDA SR)
# 2  02001       B1356                         ALLSPICE

# %%
df_food_fdg.shape
# Out:
# (7793, 15)

# %%
df_food_fdg.columns
# Out:
# Index(['NDB_No', 'FdGrp_Cd', 'Long_Desc', 'Shrt_Desc', 'ComName',
#        'ManufacName', 'Survey', 'Ref_desc', 'Refuse', 'SciName', 'N_Factor',
#        'Pro_Factor', 'Fat_Factor', 'CHO_Factor', 'FdGrp_Desc'],
#       dtype='object')

# %%
#  View all the food_des data with food group code as '0100'
dfs['FOOD_DES'][dfs['FOOD_DES']['FdGrp_Cd']=='0100'].head(3)
# Out:
#   NDB_No FdGrp_Cd                   Long_Desc               Shrt_Desc ComName  \
# 0  01001     0100              Butter, salted        BUTTER,WITH SALT     NaN
# 1  01002     0100  Butter, whipped, with salt  BUTTER,WHIPPED,W/ SALT     NaN
# 2  01003     0100       Butter oil, anhydrous    BUTTER OIL,ANHYDROUS     NaN
#
#   ManufacName Survey Ref_desc  Refuse SciName  N_Factor  Pro_Factor  \
# 0         NaN      Y      NaN     0.0     NaN      6.38        4.27
# 1         NaN      Y      NaN     0.0     NaN      6.38         NaN
# 2         NaN      Y      NaN     0.0     NaN      6.38        4.27
#
#    Fat_Factor  CHO_Factor
# 0        8.79        3.87
# 1         NaN         NaN
# 2        8.79        3.87

# %%
# different food groups 
df_food_fdg['FdGrp_Desc'].value_counts()
# Out:
# FdGrp_Desc
# Beef Products                          954
# Vegetables and Vegetable Products      814
# Baked Products                         517
# Lamb, Veal, and Game Products          464
# Poultry Products                       383
# Beverages                              366
# Sweets                                 358
# Fruits and Fruit Juices                355
# Baby Foods                             345
# Pork Products                          336
# Fast Foods                             312
# Dairy and Egg Products                 291
# Legumes and Legume Products            290
# Finfish and Shellfish Products         264
# Soups, Sauces, and Gravies             254
# Fats and Oils                          216
# Breakfast Cereals                      195
# Cereal Grains and Pasta                181
# Snacks                                 176
# Sausages and Luncheon Meats            167
# American Indian/Alaska Native Foods    165
# Nut and Seed Products                  137
# Restaurant Foods                       109
# Meals, Entrees, and Side Dishes         81
# Spices and Herbs                        63
# Name: count, dtype: int64

# %%
# all foods that belong to restaraunt foods
df_food_fdg[df_food_fdg['FdGrp_Desc']=='Restaurant Foods'].head(3)
# Out:
#      NDB_No FdGrp_Cd                             Long_Desc  \
# 7462  36000     3600  APPLEBEE'S, 9 oz house sirloin steak
# 7463  36001     3600      APPLEBEE'S, Double Crunch Shrimp
# 7464  36002     3600              APPLEBEE'S, french fries
#
#                                 Shrt_Desc                  ComName  \
# 7462  APPLEBEE'S,9 OZ HOUSE SIRLOIN STEAK  family style, applebees
# 7463      APPLEBEE'S,DOUBLE CRUNCH SHRIMP  family style, applebees
# 7464                 APPLEBEE'S,FRENCH FR  family style, applebees
#
#      ManufacName Survey Ref_desc  Refuse SciName  N_Factor  Pro_Factor  \
# 7462  Applebee's    NaN      NaN     0.0     NaN       NaN         NaN
# 7463  Applebee's    NaN      NaN     0.0     NaN       NaN         NaN
# 7464  Applebee's    NaN      NaN     0.0     NaN       NaN         NaN
#
#       Fat_Factor  CHO_Factor        FdGrp_Desc
# 7462         NaN         NaN  Restaurant Foods
# 7463         NaN         NaN  Restaurant Foods
# 7464         NaN         NaN  Restaurant Foods

# %%
df_food_fdg[(df_food_fdg['FdGrp_Desc']=='Restaurant Foods')]['ManufacName'].value_counts()
# Out:
# ManufacName
# Denny's                     12
# Applebee's                  11
# Cracker Barrel              10
# T.G.I Friday's               7
# Darden Group                 5
# Carrabba's Italian Grill     5
# Name: count, dtype: int64

# %%
# all foods that belong to restaraunt foods - APPLEBEE'S,FRENCH FR
df_food_fdg[((df_food_fdg['FdGrp_Desc']=='Restaurant Foods') & (df_food_fdg['NDB_No']=='36002'))].head()
# Out:
#      NDB_No FdGrp_Cd                 Long_Desc             Shrt_Desc  \
# 7464  36002     3600  APPLEBEE'S, french fries  APPLEBEE'S,FRENCH FR
#
#                       ComName ManufacName Survey Ref_desc  Refuse SciName  \
# 7464  family style, applebees  Applebee's    NaN      NaN     0.0     NaN
#
#       N_Factor  Pro_Factor  Fat_Factor  CHO_Factor        FdGrp_Desc
# 7464       NaN         NaN         NaN         NaN  Restaurant Foods

# %%
# find the nutrition values in APPLEBEE'S,FRENCH FR

df_nut_data_def[df_nut_data_def['NDB_No']=='36002'].head(3)
# Out:
#        NDB_No Nutr_No  Nutr_Val  Num_Data_Pts  Std_Error  Src_Cd Deriv_Cd  \
# 144752  36002     208     290.0             0        NaN       4       NC
# 144753  36002     268    1213.0             0        NaN       4       NC
# 144754  36002     301      19.0             6        1.0       1        A
#
#        Ref_NDB_No Add_Nutr_Mark  Num_Studies  ...   DF  Low_EB  Up_EB  \
# 144752        NaN           NaN          NaN  ...  NaN     NaN    NaN
# 144753        NaN           NaN          NaN  ...  NaN     NaN    NaN
# 144754        NaN           NaN          1.0  ...  5.0    16.0   21.0
#
#         Stat_cmt  AddMod_Date Units     Tagname     NutrDesc Num_Dec SR_Order
# 144752       NaN   03/01/2013  kcal  ENERC_KCAL       Energy       0      300
# 144753       NaN   03/01/2013    kJ    ENERC_KJ       Energy       0      400
# 144754      2, 3   03/01/2013    mg          CA  Calcium, Ca       0     5300
#
# [3 rows x 22 columns]

# %%
dfs['WEIGHT'][dfs['WEIGHT']['NDB_No']=='36002']
# Out:
#       NDB_No Seq  Amount Msre_Desc  Gm_Wgt  Num_Data_Pts  Std_Dev
# 13866  36002   1     1.0   serving   164.0          12.0    32.16

# %%
fast_foods_df=df_food_fdg[df_food_fdg['FdGrp_Desc']=='Fast Foods']

# %%
# Get Cholesterol for Fast foods, biscuit, with egg and bacon
df_nut_data_def[(df_nut_data_def['NDB_No']=='21003') &(df_nut_data_def['NutrDesc']=='Cholesterol')]['Nutr_Val']
# Out:
# 119640    235.0
# Name: Nutr_Val, dtype: float64

# %%
import os

# Create the directory if it doesn't exist
directory = './prepared_data'
if not os.path.exists(directory):
    os.makedirs(directory)

# Save data frames to CSV files
df_food_fdg.to_csv(os.path.join(directory, 'food_descr.csv'))
df_nut_data_def.to_csv(os.path.join(directory, 'nutr_descr.csv'))

# %%
# load food and nutrient description data frames to csv
df_food_fdg.to_csv('./prepared_data/food_descr.csv')
df_nut_data_def.to_csv('./prepared_data/nutr_descr.csv')
